# %%
import pandas as pd
import numpy as np
import requests
import re

# %% [markdown]
# ##### Token below is to access API key for presupuesto abierto
# Link to source: https://www.presupuestoabierto.gob.ar/api/

# %%
token = "30338571-3593-47f1-8b64-351a6aeacac3"

# %% [markdown]
# #### Requirements to access data:
# - Requires 3 parameters:
#     - columns you want to access
#     - Years of data
#     - filters

# %%
def pull_budget_data(years: list[int], columns: list[str], filters: list[dict], token: str) -> pd.DataFrame:
    
    url = "https://www.presupuestoabierto.gob.ar/api/v1/credito"
    headers = {
        "Authorization": token,  # you can access this token via presupuesto abierto
        "Content-Type": "application/json"
    }
    parameters = {
        "title": "Gastos por jurisdicción",
        "ejercicios": years, # years of data you want to pull (in this format --> [2022]
        "columns": columns, # These are the columns that we will access (in a list format)
        "filters": filters  # These are the filters that we set (in a list format)
    }
    
    response = requests.post(url, headers=headers, json=parameters)
    if response.status_code == 200:
        print("Request successful")
        # Decode the response content using utf-8-sig codec
        decoded_response = response.content.decode("utf-8-sig")
        lines = decoded_response.split('\n') # The response returns a bunch of lines, each line is a new row of data
        headers = re.split(r',(?!\s)', lines[0]) # Uses a regular expression to split each column based on the commas. It must be a comma with no space directly after, as in these cases, it is a program name. This specifically represents the column names
        elements = []
        # The loop below goes through each line and creates a list for each line. These are our rows
        for i in range(1, len(lines)):
            # Split the string using a regular expression pattern and add to list with all the lines
            elements.append(re.split(r',(?!\s)', lines[i])) 
    
        budget_data = pd.DataFrame(elements[:-1], columns = headers) # creates a dataframe based on the above up to the second to last row since last line did not have any data
        
        # Three lines below convert format of data to float
        budget_data['credito_presupuestado'] = budget_data['credito_presupuestado'].astype(float)
        budget_data['credito_vigente'] = budget_data['credito_vigente'].astype(float)
        budget_data['credito_devengado'] = budget_data['credito_devengado'].astype(float)
    
    else:
        print("Failed to make request:", response.text)
        budget_data = 'NA'
    return budget_data

# %%
years = [2024]
columns = [
    "caracter_id",
    "caracter_desc",
    "funcion_desc",
    "ejercicio_presupuestario",
    "credito_presupuestado",
    "credito_vigente",
    "credito_devengado"
    ]
filters = []

pull_budget_data(years, columns, filters, token)
# Out:
# Request successful
#    caracter_id                      caracter_desc  \
# 0            1             Administración Central
# 1            1             Administración Central
# 2            1             Administración Central
# 3            1             Administración Central
# 4            1             Administración Central
# 5            1             Administración Central
# 6            1             Administración Central
# 7            1             Administración Central
# 8            1             Administración Central
# 9            1             Administración Central
# 10           1             Administración Central
# 11           1             Administración Central
# 12           1             Administración Central
# 13           1             Administración Central
# 14           1             Administración Central
# 15           1             Administración Central
# 16           1             Administración Central
# 17           1             Administración Central
# 18           1             Administración Central
# 19           1             Administración Central
# 20           1             Administración Central
# 21           1             Administración Central
# 22           1             Administración Central
# 23           1             Administración Central
# 24           1             Administración Central
# 25           1             Administración Central
# 26           1             Administración Central
# 27           1             Administración Central
# 28           1             Administración Central
# 29           2        Organismos Descentralizados
# 30           2        Organismos Descentralizados
# 31           2        Organismos Descentralizados
# 32           2        Organismos Descentralizados
# 33           2        Organismos Descentralizados
# 34           2        Organismos Descentralizados
# 35           2        Organismos Descentralizados
# 36           2        Organismos Descentralizados
# 37           2        Organismos Descentralizados
# 38           2        Organismos Descentralizados
# 39           2        Organismos Descentralizados
# 40           2        Organismos Descentralizados
# 41           2        Organismos Descentralizados
# 42           2        Organismos Descentralizados
# 43           2        Organismos Descentralizados
# 44           2        Organismos Descentralizados
# 45           2        Organismos Descentralizados
# 46           2        Organismos Descentralizados
# 47           2        Organismos Descentralizados
# 48           2        Organismos Descentralizados
# 49           2        Organismos Descentralizados
# 50           2        Organismos Descentralizados
# 51           3  Instituciones de Seguridad Social
# 52           3  Instituciones de Seguridad Social
#
#                              funcion_desc ejercicio_presupuestario  \
# 0                   Administración Fiscal                     2024
# 1        "Agricultura, Ganadería y Pesca"                     2024
# 2           Agua Potable y Alcantarillado                     2024
# 3      "Ciencia, Tecnología e Innovación"                     2024
# 4   "Comercio, Turismo y Otros Servicios"                     2024
# 5                          Comunicaciones                     2024
# 6           Control de la Gestión Pública                     2024
# 7                                 Defensa                     2024
# 8            Dirección Superior Ejecutiva                     2024
# 9        Ecología y Desarrollo Sostenible                     2024
# 10                    Educación y Cultura                     2024
# 11      "Energía, Combustibles y Minería"                     2024
# 12                              Industria                     2024
# 13      Información y Estadística Básicas                     2024
# 14                           Inteligencia                     2024
# 15                               Judicial                     2024
# 16                            Legislativa                     2024
# 17          Promoción y Asistencia Social                     2024
# 18                  Relaciones Exteriores                     2024
# 19                  Relaciones Interiores                     2024
# 20                                  Salud                     2024
# 21                     Seguridad Interior                     2024
# 22                       Seguridad Social                     2024
# 23                     Seguros y Finanzas                     2024
# 24           Servicio de la Deuda Pública                     2024
# 25                          Sistema Penal                     2024
# 26                                Trabajo                     2024
# 27                             Transporte                     2024
# 28                   Vivienda y Urbanismo                     2024
# 29                  Administración Fiscal                     2024
# 30       "Agricultura, Ganadería y Pesca"                     2024
# 31          Agua Potable y Alcantarillado                     2024
# 32     "Ciencia, Tecnología e Innovación"                     2024
# 33  "Comercio, Turismo y Otros Servicios"                     2024
# 34                         Comunicaciones                     2024
# 35          Control de la Gestión Pública                     2024
# 36           Dirección Superior Ejecutiva                     2024
# 37       Ecología y Desarrollo Sostenible                     2024
# 38                    Educación y Cultura                     2024
# 39      "Energía, Combustibles y Minería"                     2024
# 40                              Industria                     2024
# 41                               Judicial                     2024
# 42          Promoción y Asistencia Social                     2024
# 43                  Relaciones Interiores                     2024
# 44                                  Salud                     2024
# 45                     Seguridad Interior                     2024
# 46                       Seguridad Social                     2024
# 47                     Seguros y Finanzas                     2024
# 48           Servicio de la Deuda Pública                     2024
# 49                                Trabajo                     2024
# 50                             Transporte                     2024
# 51                                  Salud                     2024
# 52                       Seguridad Social                     2024
#
#     credito_presupuestado  credito_vigente  credito_devengado
